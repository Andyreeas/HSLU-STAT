# %% [markdown]
# # Erklärung $R^2$

# %%
import pandas as pd 
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import abline_plot
from scipy.stats import uniform, norm
import matplotlib.pyplot as plt
import numpy as np

x = uniform.rvs(size=20, loc=0, scale=10)
y = x 

df = pd.DataFrame({"x":x,"y":y})
df


Y = df["y"]
X = df["x"]
X = sm.add_constant(X)

fit = sm.OLS(Y,X).fit()

ax = df.plot(kind="scatter",x="x", y="y")
abline_plot(model_results=fit, ax = ax, color="orange")
plt.show()

# %%
ax = df.plot(kind="scatter",x="x", y="y")
abline_plot(model_results=fit, ax = ax, color="orange")
for i in range(0,20):
    plt.plot([x[i],x[i]],[Y[i],np.mean(Y)], color="red")
    
plt.plot([0,10],[np.mean(y),np.mean(y)])

# %%
df.corr()
# Out:
#      x    y
# x  1.0  1.0
# y  1.0  1.0

# %%
fit.rsquared
# Out:
# 1.0

# %%
Y.var()
# Out:
# 5.018669658675495

# %%
x = uniform.rvs(size=20, loc=0, scale=10)
y = x + norm.rvs(size=20, loc=0, scale=)

df = pd.DataFrame({"x":x,"y":y})
df


Y = df["y"]
X = df["x"]
X = sm.add_constant(X)

fit = sm.OLS(Y,X).fit()

ax = df.plot(kind="scatter",x="x", y="y")
abline_plot(model_results=fit, ax = ax, color="orange")
plt.show()

# %%
df.corr()
# Out:
#           x         y
# x  1.000000  0.998111
# y  0.998111  1.000000

# %%
fit.rsquared
# Out:
# 0.9962259087284749

# %%
Y.var()
# Out:
# 8.98948311509543

# %%
x = uniform.rvs(size=20, loc=0, scale=10)
y = x + norm.rvs(size=20, loc=0, scale=4)

df = pd.DataFrame({"x":x,"y":y})
df


Y = df["y"]
X = df["x"]
X = sm.add_constant(X)

fit = sm.OLS(Y,X).fit()

ax = df.plot(kind="scatter",x="x", y="y")
abline_plot(model_results=fit, ax = ax, color="orange")
plt.show()

# %%
df.corr()
# Out:
#           x         y
# x  1.000000  0.628728
# y  0.628728  1.000000

# %%
fit.rsquared
# Out:
# 0.3775975144388716

# %%
Y.var()
# Out:
# 15.256448332374813

# %%
x = uniform.rvs(size=20, loc=0, scale=10)
y = x**2

df = pd.DataFrame({"x":x,"y":y})
df

ax = df.plot(kind="scatter",x="x", y="y")
Y = df["y"]
X = df["x"]
X = sm.add_constant(X)
fit = sm.OLS(Y,X).fit()
abline_plot(model_results=fit, ax = ax, color="orange")
weights = np.polyfit(x, y, 2)
model = np.poly1d(weights)
fit = sm.OLS(Y,model(X)).fit()

x_g = np.linspace(0,10)
y_g = x_g**2



plt.plot(x_g,y_g, linewidth=.5)
plt.show()

# %%
df.corr()
# Out:
#           x         y
# x  1.000000  0.970625
# y  0.970625  1.000000

# %%
fit.rsquared
# Out:
# 1.0

# %%
Y.var()
# Out:
# 990.4818687620036

# %%
x = uniform.rvs(size=20, loc=0, scale=10)
y = x**2 + norm.rvs(size=20, loc=0, scale=4)

df = pd.DataFrame({"x":x,"y":y})
df

ax = df.plot(kind="scatter",x="x", y="y")
Y = df["y"]
X = df["x"]
X = sm.add_constant(X)
fit = sm.OLS(Y,X).fit()
abline_plot(model_results=fit, ax = ax, color="orange")
weights = np.polyfit(x, y, 2)
model = np.poly1d(weights)
fit = sm.OLS(Y,model(X)).fit()

x_g = np.linspace(0,10)
y_g = x_g**2



plt.plot(x_g,y_g, linewidth=.5)
plt.show()

# %%
df.corr()
# Out:
#           x         y
# x  1.000000  0.960072
# y  0.960072  1.000000

# %%
fit.rsquared
# Out:
# 0.9818951075679724

# %%
Y.var()
# Out:
# 1285.3816338985698

# %%
x = uniform.rvs(size=20, loc=0, scale=10)
y = x**2 + norm.rvs(size=20, loc=0, scale=20)

df = pd.DataFrame({"x":x,"y":y})
df

ax = df.plot(kind="scatter",x="x", y="y")
Y = df["y"]
X = df["x"]
X = sm.add_constant(X)
fit = sm.OLS(Y,X).fit()
abline_plot(model_results=fit, ax = ax, color="orange")
weights = np.polyfit(x, y, 2)
model = np.poly1d(weights)
fit = sm.OLS(Y,model(X)).fit()

x_g = np.linspace(0,10)
y_g = x_g**2



plt.plot(x_g,y_g, linewidth=.5)
plt.show()

# %%
df.corr()
# Out:
#          x        y
# x  1.00000  0.86313
# y  0.86313  1.00000

# %%
fit.rsquared
# Out:
# 0.857886520467937

# %%
Y.var()
# Out:
# 984.7238001883243
